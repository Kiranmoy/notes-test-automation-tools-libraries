# %% [markdown]
# # Installation

# %% [markdown]
# ```bash
# pip install playwright
#
# playwright --version
#
# playwright install # This downloads necessary browser drivers that palywright needs.
# ```

# %% [markdown]
# # First Playwright Script

# %% [markdown]
# ```python
# from playwright.sync_api import sync_playwright
#
# playwright = sync_playwright().start();
#
#  # Launch a browser (By default playwright runs in headless=True mode)
# browser = playwright.chromium.launch(headless=False,slow_mo=1000)
#
# # Create a new tab/page
# page = browser.new_page()
#
# # visit playwright website
# page.goto("https://playwright.dev/python")
#
# # Locate a Link element with "Docs" text
# docs_button = page.get_by_role('link', name="Docs")
# docs_button.click()
#
# # Get the URL
# print("Playwright Python Docs: ", page.url)
#
# # close browser
# browser.close()
#
# playwright.stop()
# ```

# %% [markdown]
# # Launch Browser using Context Manager

# %% [markdown]
# ```python
# from playwright.sync_api import sync_playwright
#
# with sync_playwright() as playwright:
#
#     # Launch a browser (By default, playwright runs in headless=True mode)
#     browser = playwright.chromium.launch(headless=False,slow_mo=1000)
#
#     # Create a new tab/page
#     page = browser.new_page()
#
#     # visit the playwright website
#     page.goto("https://playwright.dev/python")
#
#     # Locate a Link element with "Docs" text
#     docs_button = page.get_by_role('link', name="Docs")
#     docs_button.click()
#
#     # Get the URL
#     print("Playwright Python Docs: ", page.url)
#
#     # close browser
#     browser.close()
#
#
# ```

# %% [markdown]
# > **NOTE**: By default, playwright waits for 30000 mS to locate element before throwing element not found exception.

# %% [markdown]
# # Popular Practice Websites

# %% [markdown]
# * All webelement: https://bootswatch.com/default/
# * Images: https://unsplash.com/
# * Scrape This Site: https://www.scrapethissite.com/
# * UI test automation playground: http://uitestingplayground.com/
# * DummyJSON: https://dummyjson.com/
#
# ---
#
# * Automation Book Store: https://automationbookstore.dev/
# * Automation Test Store: https://automationteststore.com/
# * DemoBlaze: https://www.demoblaze.com/
# * DemoQA: https://demoqa.com/
# * ParaBank: https://parabank.parasoft.com/parabank/index.htm
# * LetCode: https://letcode.in/test
# * SelectorHub: https://selectorshub.com/xpath-practice-page/
# * Selenium Test Pages: https://testpages.herokuapp.com/styled/index.html
# * Swag Labs: https://www.saucedemo.com/
# * The Internet: https://the-internet.herokuapp.com/
# * XYZ Bank: https://www.globalsqa.com/angularJs-protractor/BankingProject/#/login
