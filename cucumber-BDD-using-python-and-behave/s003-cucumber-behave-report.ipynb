# %% [markdown]
# # Generating Bheave Reports Overview

# %% [markdown]
# **Formatters** is a **behave** module that produces test execution results in various formats.
#
# **`behave --format help`**: shows all available formats in which behave can produce output.
#
# ![image.png](attachment:423ca5b6-df8c-4c48-9646-86b36ce6b46e.png)

# %% [markdown]
# # How to output Junit compatible xml?

# %% [markdown]
# **`behave --junit --junit-directory my_junit_output`**
#
# > Parse the junit json/xml to generate CUSTOM REPORT.

# %% [markdown]
# # How to output JSON report?

# %% [markdown]
# **`behave --format json.pretty -o my_json_out.json`**
#
# > Parse the JSON to generate CUSTOM REPORT.

# %% [markdown]
# # How to generate Allure report?

# %% [markdown]
# To generate an Allure report for behave, we need two components:
# 1. Install Allure: **https://allurereport.org/docs/install-for-windows/**
# 2. Install **`allure-behave`** library: **https://pypi.org/project/allure-behave/**
